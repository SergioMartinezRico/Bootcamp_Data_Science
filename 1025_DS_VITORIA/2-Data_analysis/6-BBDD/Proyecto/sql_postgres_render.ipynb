# %% [markdown]
# # Conexión a una base de datos Online. Render en nuestro caso

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
def conexion(hosting, puerto, nombre_db, usuario, pswd):
        conn = psycopg2.connect(
                host = hosting,
                port = puerto,
                dbname = nombre_db,
                user = usuario,
                password = pswd
        )
        cursor = conn.cursor()
        return conn, cursor

def sql_query(query,cursor):   # SELECT * FROM TRACKS

    # Ejecuta la query
    cursor.execute(query)

    # Almacena los datos de la query 
    ans = cursor.fetchall()

    # Obtenemos los nombres de las columnas de la tabla
    names = [description[0] for description in cursor.description]

    return pd.DataFrame(ans,columns=names)

def sql_insert(query,cursor):
  try:
    cursor.execute(query)
    return "OK"
  except:
    return "error"

# %%
hosting = "dpg-d4eup28gjchc73fpd0q0-a.oregon-postgres.render.com"
puerto = "5432"
nombre_db = "proyecto_bbdd_8wcv"
usuario = "admin"
pswd = "u3BkUaIcfmFxjJusrCM2OP0plh4LNSUb"

# %%
conn, cursor = conexion(hosting, puerto, nombre_db, usuario, pswd)

# %%
print (cursor)
# Out:
# <cursor object at 0x000002144A2FB680; closed: 0>

# %%
df_1 = pd.read_csv("./data/clase_1.csv", sep=";")
df_2 = pd.read_csv("./data/clase_2.csv", sep=";")
df_3 = pd.read_csv("./data/clase_3.csv", sep=";")
df_4 = pd.read_csv("./data/clase_4.csv", sep=";")
df_c = pd.read_csv("./data/claustro.csv", sep=";")

# %%
hosting = "dpg-d4eup28gjchc73fpd0q0-a.oregon-postgres.render.com"
puerto = "5432"
nombre_db = "proyecto_bbdd_8wcv"
usuario = "admin"
pswd = "u3BkUaIcfmFxjJusrCM2OP0plh4LNSUb"

# %%
engine = create_engine("postgresql://admin:u3BkUaIcfmFxjJusrCM2OP0plh4LNSUb@dpg-d4eup28gjchc73fpd0q0-a.frankfurt-postgres.render.com/proyecto_bbdd_8wcv")
# df.to_sql("tabla", engine ,if_exists="append", index=False)

# %%
df_1
# Out:
#                   Nombre                           Email   Promoción  \
# 0           Jafet Casals          Jafet_Casals@gmail.com  Septiembre
# 1       Jorge Manzanares      Jorge_Manzanares@gmail.com  Septiembre
# 2          Onofre Adadia         Onofre_Adadia@gmail.com  Septiembre
# 3           Merche Prada          Merche_Prada@gmail.com  Septiembre
# 4           Pilar Abella          Pilar_Abella@gmail.com  Septiembre
# 5           Leoncio Tena          Leoncio_Tena@gmail.com  Septiembre
# 6        Odalys Torrijos       Odalys_Torrijos@gmail.com  Septiembre
# 7       Eduardo Caparrós      Eduardo_Caparrós@gmail.com  Septiembre
# 8     Ignacio Goicoechea    Ignacio_Goicoechea@gmail.com  Septiembre
# 9      Clementina Santos     Clementina_Santos@gmail.com  Septiembre
# 10         Daniela Falcó         Daniela_Falcó@gmail.com  Septiembre
# 11         Abraham Vélez         Abraham_Vélez@gmail.com  Septiembre
# 12  Maximiliano Menéndez  Maximiliano_Menéndez@gmail.com  Septiembre
# ...

# %%
df_alumnos1 = df_1.loc[:,("Nombre", "Email", "Fecha_comienzo")]
df_alumnos2 = df_2.loc[:,("Nombre", "Email", "Fecha_comienzo")]
df_alumnos3 = df_3.loc[:,("Nombre", "Email", "Fecha_comienzo")]
df_alumnos4 = df_4.loc[:,("Nombre", "Email", "Fecha_comienzo")]

df_alumnos_total = pd.concat([df_alumnos1,df_alumnos2,df_alumnos3,df_alumnos4], ignore_index=True)

# %%
df_alumnos_total[['Nombre', 'Apellidos']] = df_alumnos_total['Nombre'].str.split(' ', n=1, expand=True)
df_alumnos_total
# Out:
#          Nombre                           Email Fecha_comienzo      Apellidos
# 0         Jafet          Jafet_Casals@gmail.com     18/09/2023         Casals
# 1         Jorge      Jorge_Manzanares@gmail.com     18/09/2023     Manzanares
# 2        Onofre         Onofre_Adadia@gmail.com     18/09/2023         Adadia
# 3        Merche          Merche_Prada@gmail.com     18/09/2023          Prada
# 4         Pilar          Pilar_Abella@gmail.com     18/09/2023         Abella
# 5       Leoncio          Leoncio_Tena@gmail.com     18/09/2023           Tena
# 6        Odalys       Odalys_Torrijos@gmail.com     18/09/2023       Torrijos
# 7       Eduardo      Eduardo_Caparrós@gmail.com     18/09/2023       Caparrós
# 8       Ignacio    Ignacio_Goicoechea@gmail.com     18/09/2023     Goicoechea
# 9    Clementina     Clementina_Santos@gmail.com     18/09/2023         Santos
# 10      Daniela         Daniela_Falcó@gmail.com     18/09/2023          Falcó
# ...

# %%
df_alumnos_total = df_alumnos_total[['Nombre', 'Apellidos', 'Email', 'Fecha_comienzo']]

# %%
df_alumnos_total
# Out:
#          Nombre      Apellidos                           Email Fecha_comienzo
# 0         Jafet         Casals          Jafet_Casals@gmail.com     18/09/2023
# 1         Jorge     Manzanares      Jorge_Manzanares@gmail.com     18/09/2023
# 2        Onofre         Adadia         Onofre_Adadia@gmail.com     18/09/2023
# 3        Merche          Prada          Merche_Prada@gmail.com     18/09/2023
# 4         Pilar         Abella          Pilar_Abella@gmail.com     18/09/2023
# 5       Leoncio           Tena          Leoncio_Tena@gmail.com     18/09/2023
# 6        Odalys       Torrijos       Odalys_Torrijos@gmail.com     18/09/2023
# 7       Eduardo       Caparrós      Eduardo_Caparrós@gmail.com     18/09/2023
# 8       Ignacio     Goicoechea    Ignacio_Goicoechea@gmail.com     18/09/2023
# 9    Clementina         Santos     Clementina_Santos@gmail.com     18/09/2023
# 10      Daniela          Falcó         Daniela_Falcó@gmail.com     18/09/2023
# ...

# %%
df_c
# Out:
#                Nombre Rol Vertical   Promocion    Campus   Modalidad
# 0           Noa Yáñez  TA       DS  Septiembre    Madrid  Presencial
# 1   Saturnina Benitez  TA       DS  Septiembre    Madrid  Presencial
# 2          Anna Feliu  TA       FS  Septiembre    Madrid  Presencial
# 3       Rosalva Ayuso  TA       FS  Septiembre  Valencia  Presencial
# 4    Ana Sofía Ferrer  TA       FS     Febrero  Valencia  Presencial
# 5     Angélica Corral  TA       FS     Febrero    Madrid  Presencial
# 6         Ariel Lledó  TA       DS  Septiembre    Madrid  Presencial
# 7         Mario Prats  LI       FS     Febrero  Valencia      Online
# 8   Luis Ángel Suárez  LI       FS  Septiembre    Madrid      Online
# 9  María Dolores Diaz  LI       DS  Septiembre    Madrid      Online

# %%
#df_alumnos_total = df_alumnos_total[['Nombre', 'Apellidos', 'Email', 'Fecha_comienzo']]
df_profesores = df_c[["Nombre","Vertical"]]

# %%
df_profesores[['Nombre', 'Apellidos']] = df_profesores['Nombre'].str.split(' ', n=1, expand=True)

# %%
df_profesores
# Out:
#       Nombre Vertical     Apellidos
# 0        Noa       DS         Yáñez
# 1  Saturnina       DS       Benitez
# 2       Anna       FS         Feliu
# 3    Rosalva       FS         Ayuso
# 4        Ana       FS  Sofía Ferrer
# 5   Angélica       FS        Corral
# 6      Ariel       DS         Lledó
# 7      Mario       FS         Prats
# 8       Luis       FS  Ángel Suárez
# 9      María       DS  Dolores Diaz

# %%
df_profesores = df_profesores[["Nombre","Apellidos", "Vertical"]]

# %%
df_profesores
# Out:
#       Nombre     Apellidos Vertical
# 0        Noa         Yáñez       DS
# 1  Saturnina       Benitez       DS
# 2       Anna         Feliu       FS
# 3    Rosalva         Ayuso       FS
# 4        Ana  Sofía Ferrer       FS
# 5   Angélica        Corral       FS
# 6      Ariel         Lledó       DS
# 7      Mario         Prats       FS
# 8       Luis  Ángel Suárez       FS
# 9      María  Dolores Diaz       DS

# %%
# Corregir fila 4
df_profesores.loc[4, 'Nombre'] = 'Ana Sofía'
df_profesores.loc[4, 'Apellidos'] = 'Ferrer'

# Corregir fila 8
df_profesores.loc[8, 'Nombre'] = 'Luis Ángel'
df_profesores.loc[8, 'Apellidos'] = 'Suárez'

# Corregir fila 9
df_profesores.loc[9, 'Nombre'] = 'María Dolores'
df_profesores.loc[9, 'Apellidos'] = 'Diaz'

# %%
df_profesores
# Out:
#           Nombre Apellidos Vertical
# 0            Noa     Yáñez       DS
# 1      Saturnina   Benitez       DS
# 2           Anna     Feliu       FS
# 3        Rosalva     Ayuso       FS
# 4      Ana Sofía    Ferrer       FS
# 5       Angélica    Corral       FS
# 6          Ariel     Lledó       DS
# 7          Mario     Prats       FS
# 8     Luis Ángel    Suárez       FS
# 9  María Dolores      Diaz       DS

# %%
# Crear columna alumno_id empezando en 1
df_alumnos_total['alumno_id'] = range(1, len(df_alumnos_total) + 1)

# %%
# Reordenar columnas para que alumno_id quede al principio
df_alumnos_total = df_alumnos_total[['alumno_id', 'Nombre', 'Apellidos', 'Email', 'Fecha_comienzo']]

# %%
df_alumnos_total
# Out:
#     alumno_id       Nombre      Apellidos                           Email  \
# 0           1        Jafet         Casals          Jafet_Casals@gmail.com
# 1           2        Jorge     Manzanares      Jorge_Manzanares@gmail.com
# 2           3       Onofre         Adadia         Onofre_Adadia@gmail.com
# 3           4       Merche          Prada          Merche_Prada@gmail.com
# 4           5        Pilar         Abella          Pilar_Abella@gmail.com
# 5           6      Leoncio           Tena          Leoncio_Tena@gmail.com
# 6           7       Odalys       Torrijos       Odalys_Torrijos@gmail.com
# 7           8      Eduardo       Caparrós      Eduardo_Caparrós@gmail.com
# 8           9      Ignacio     Goicoechea    Ignacio_Goicoechea@gmail.com
# 9          10   Clementina         Santos     Clementina_Santos@gmail.com
# 10         11      Daniela          Falcó         Daniela_Falcó@gmail.com
# 11         12      Abraham          Vélez         Abraham_Vélez@gmail.com
# ...

# %%
# Reordenar columnas para que profesor_id quede al principio
df_profesores = df_profesores[['profesor_id', 'Nombre', 'Apellidos']]

# %%
df_profesores
# Out:
#    profesor_id         Nombre Apellidos
# 0            1            Noa     Yáñez
# 1            2      Saturnina   Benitez
# 2            3           Anna     Feliu
# 3            4        Rosalva     Ayuso
# 4            5      Ana Sofía    Ferrer
# 5            6       Angélica    Corral
# 6            7          Ariel     Lledó
# 7            8          Mario     Prats
# 8            9     Luis Ángel    Suárez
# 9           10  María Dolores      Diaz
